# %% [markdown]
# <a href="https://colab.research.google.com/github/seismosmsr/machine_learning/blob/main/AutoGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Torantulino/Auto-GPT.git
# Out:
# Cloning into 'Auto-GPT'...
# remote: Enumerating objects: 5489, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 5489 (delta 47), reused 67 (delta 38), pack-reused 5385
# Receiving objects: 100% (5489/5489), 1.71 MiB | 4.87 MiB/s, done.
# Resolving deltas: 100% (3655/3655), done.

# %%
# !cd Auto-GPT ; pip install -r requirements.txt
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 77.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.5/227.5 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 23.2 MB/s eta 0:00:00
# ...

# %%
# !cd Auto-GPT ; python -m autogpt
# Out:
# Welcome back!  Would you like me to return to being Reginald?
# Continue with the last settings?
# Name:  Reginald
# Role:  an AI that helps you research and write your PhD thesis.
# Goals: ['Research a domain and develop an introductory chapter.', 'Develop a literature review', 'Write up results.']
# Continue (y/n): n
# Welcome to Auto-GPT!  Enter the name of your AI and its role below. Entering nothing will load defaults.
# Name your AI:  For example, 'Entrepreneur-GPT'
# AI Name: Regina
# Regina here!  I am at your service.
# Describe your AI's role:  For example, 'an AI designed to autonomously develop and run businesses with the sole goal of increasing your net worth.'
# Regina is: an AI that writes blog posts automatically about current topics in climate change.
# Enter up to 5 goals for your AI:  For example: Increase net worth, Grow Twitter Account, Develop and manage multiple businesses autonomously'
# Enter nothing to load defaults, enter nothing when finished.
# ...
